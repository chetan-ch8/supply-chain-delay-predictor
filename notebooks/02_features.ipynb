# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

df = pd.read_csv("../data/processed/model_features.csv")
print(df.shape)
df.head()
# Out:
# (94612, 9)
#    distance_km  product_weight_g  freight_value  day_of_week  \
# 0   565.959812            1000.0           8.49            3
# 1   708.754247             300.0          15.56            0
# 2   915.912412             400.0          17.19            0
# 3   818.146504             767.0          17.24            0
# 4   212.014865            2050.0          13.56            0
#
#    seller_avg_delay_historical  category_encoded  state_encoded  \
# 0                   -11.192326                43             25
# 1                   -11.192326                70             25
# 2                   -11.192326                65             22
# 3                   -11.192326                65             22
# 4                   -11.192326                39             25
#
#    delivery_delay_days  is_late
# 0            36.324745        1
# 1            -0.415127        0
# 2           -10.236366        0
# 3           -25.542975        0
# 4           -22.536319        0

# %%
df.describe().T
# Out:
#                                count         mean          std         min  \
# distance_km                  94612.0   601.307614   593.284049    0.000000
# product_weight_g             94612.0  2101.857587  3750.967928    2.000000
# freight_value                94612.0    22.821484    21.636020    0.000000
# day_of_week                  94612.0     2.755993     1.967028    0.000000
# seller_avg_delay_historical  94612.0   -12.082720     5.099469 -139.397396
# category_encoded             94612.0    39.243479    22.723589    0.000000
# state_encoded                94612.0    18.678128     7.067968    0.000000
# delivery_delay_days          94612.0   -11.192326    10.187081 -146.016123
# is_late                      94612.0     0.080878     0.272649    0.000000
#
#                                     25%         50%          75%           max
# distance_km                  187.718788  434.330144   799.133877   5338.619521
# product_weight_g             300.000000  700.000000  1800.000000  40425.000000
# freight_value                 13.840000   17.210000    24.072500   1794.960000
# day_of_week                    1.000000    3.000000     4.000000      6.000000
# seller_avg_delay_historical  -13.855137  -11.333547    -9.540306    152.683171
# category_encoded              15.000000   43.000000    63.000000     70.000000
# state_encoded                 12.000000   22.000000    25.000000     26.000000
# delivery_delay_days          -16.251149  -11.968837    -6.391267    188.975081
# is_late                        0.000000    0.000000     0.000000      1.000000

# %%
corr = df.corr(numeric_only=True)
fig, ax = plt.subplots(figsize=(10, 6))
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", center=0, ax=ax)
plt.title("Feature / target correlation matrix")
plt.show()

# %%
print(df[["seller_avg_delay_historical", "delivery_delay_days"]].corr())
# Out:
#                              seller_avg_delay_historical  delivery_delay_days
# seller_avg_delay_historical                     1.000000             0.237486
# delivery_delay_days                             0.237486             1.000000
